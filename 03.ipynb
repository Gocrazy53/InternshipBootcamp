# %% [markdown]
# <a href="https://colab.research.google.com/github/Gocrazy53/InternshipBootcamp/blob/main/Class3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#First Step - Import library
import pandas as pd

#Second Step - Import Data
Salary = pd.read_csv('https://github.com/YBI-Foundation/Dataset/raw/main/Salary%20Data.csv')
Salary.head()
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525

# %%
Salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Experience Years  40 non-null     float64
#  1   Salary            40 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 768.0 bytes

# %%
Salary.describe()
# Out:
#        Experience Years         Salary
# count         40.000000      40.000000
# mean           5.152500   74743.625000
# std            2.663715   25947.122885
# min            1.100000   37731.000000
# 25%            3.200000   56878.250000
# 50%            4.600000   64472.500000
# 75%            6.875000   95023.250000
# max           10.500000  122391.000000

# %%
Salary.columns
# Out:
# Index(['Experience Years', 'Salary'], dtype='object')

# %%
Salary.shape
# Out:
# (40, 2)

# %%
target_unique_value = Salary['Experience Years'].unique()
print(target_unique_value)
# Out:
# [ 1.1  1.2  1.3  1.5  2.   2.2  2.5  2.9  3.   3.2  3.5  3.7  3.8  3.9
#   4.   4.1  4.3  4.5  4.7  4.9  5.1  5.3  5.5  5.9  6.   6.2  6.5  6.8
#   7.1  7.9  8.2  8.5  8.7  9.   9.5  9.6 10.3 10.5]

# %%
target_unique = Salary['Salary'].unique()
print(target_unique)
# Out:
# [ 39343  42774  46205  37731  43525  39891  48266  56642  60150  54445
#   64445  60000  57189  60200  63218  55794  56957  57081  59095  61111
#   64500  67938  66029  83088  82200  81363  93940  91000  90000  91738
#   98273 101302 113812 111620 109431 105582 116969 112635 122391 121872]

# %%
#Define Target variables x and y
x = Salary[['Experience Years']]
y = Salary['Salary']

x.shape
# Out:
# (40, 1)

# %%
y.shape
# Out:
# (40,)

# %%
# Step 4 - train test split
# Using sklearn library

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, train_size=0.7, random_state=2529)

# %%
x_train
# Out:
#     Experience Years
# 28               6.5
# 31               7.9
# 34               8.7
# 20               4.7
# 4                2.0
# 3                1.5
# 18               4.3
# 26               6.0
# 2                1.3
# 22               5.1
# 35               9.0
# 7                2.9
# 39              10.5
# 30               7.1
# 10               3.2
# 0                1.1
# 9                3.2
# 13               3.8
# 5                2.2
# 37               9.6
# 23               5.3
# 25               5.9
# 21               4.9
# 24               5.5
# 8                3.0
# 36               9.5
# 15               4.0
# 32               8.2

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((28, 1), (12, 1), (28,), (12,))
